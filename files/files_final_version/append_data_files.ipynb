# %%
import numpy as np 
import pandas as pd
import os
import file_management 

current_folder = os.getcwd()    
data_folder = os.path.join(current_folder,"test_data")  
data_folder = '/home/jaime/Desktop/hippocampus/external_inputs/baseline/'
# Create a list of all the filenames
# Initial names of all the files we are storing 
# If no file start with these names, nothing happens, no error is raised
# A message tells us that no files were found with this name

# It loads and combines all the files that start with the same name
# If this code is rerun, there will be only one file with matches the name
# and then the lzma file will be deleted and stored again, so nothing happens
filenames = []
filenames.extend(["volt_pyr_ca3_","volt_bas_ca3_","volt_olm_ca3_"])
filenames.extend(["volt_pyr_ca1_","volt_bas_ca1_","volt_olm_ca1_","volt_cck_ca1_"])
filenames.extend(["external_inputs_pyr_ca3_","spikes_bas_ca3_","spikes_olm_ca3_"])
filenames.extend(["spikes_pyr_ca1_","spikes_bas_ca1_","spikes_olm_ca1_","spikes_cck_ca1_"])
filenames.extend(["synapses_pyr_ca3_"])
filenames.extend(["synapses_pyr_ca1_"])
filenames.extend(["lfp_ca3_"])
filenames.extend(["lfp_ca1_"])
filenames.extend(["ica_ca3_"])
filenames.extend(["ica_ca1_"])
# filenames.extend([ ... ]) if necessary

print("Creating the groups of files")
print("----------------------------")
groups = [] 
groups_name = []
k = 1
for name in filenames:
    groups.append([])
    for file in os.listdir(data_folder):
        if name in file:
            groups[-1].append(file)
    if not groups[-1]:
        print(f"{k}. No files found with {name}.")
        k+=1

print(" ")
print("Combining the files and removing them")
print("-------------------------------------")
k=1
for i,group in enumerate(groups):
    if group:
        combined_df = pd.DataFrame()
        for file in group:
            df = file_management.load_lzma(os.path.join(data_folder,file))
            combined_df = pd.concat([combined_df,df],ignore_index=True)
            os.remove(os.path.join(data_folder,file))
        print(f"{k}.All data in files with {filenames[i]} were combined and stored. Files were deleted.")
        file_management.save_lzma(combined_df, f"{filenames[i]}.lzma", parent_dir=data_folder)
        k+=1
# Out:
# Creating the groups of files
# ----------------------------
# 1. No files found with volt_pyr_ca1.
# 2. No files found with volt_bas_ca1.
# 3. No files found with volt_olm_ca1.
# 4. No files found with volt_cck_ca1.
# 5. No files found with spikes_pyr_ca1.
# 6. No files found with spikes_bas_ca1.
# 7. No files found with spikes_olm_ca1.
# 8. No files found with spikes_cck_ca1.
# 9. No files found with synapses_pyr_ca1.
# 10. No files found with lfp_ca1.
# 11. No files found with ica_ca3.
# 12. No files found with ica_ca1.
#
# Combining the files and removing them
# -------------------------------------
# 1.All data in files with volt_pyr_ca3 were combined and stored. Files were deleted.
# 2.All data in files with volt_bas_ca3 were combined and stored. Files were deleted.
# 3.All data in files with volt_olm_ca3 were combined and stored. Files were deleted.
# 4.All data in files with external_inputs_pyr_ca3 were combined and stored. Files were deleted.
# 5.All data in files with spikes_bas_ca3 were combined and stored. Files were deleted.
# 6.All data in files with spikes_olm_ca3 were combined and stored. Files were deleted.
# 7.All data in files with synapses_pyr_ca3 were combined and stored. Files were deleted.
# 8.All data in files with lfp_ca3 were combined and stored. Files were deleted.
